# %%
# importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from faker import Faker

# %%
fake = Faker()
np.random.seed(42)
rows = 12000

df = pd.DataFrame({
    "package_id": np.arange(1, rows + 1),
    "driver_name": [fake.name() for _ in range(rows)],
    "delivery_city": [fake.city() for _ in range(rows)],
    "delivery_address": [fake.address().replace("\n", ", ") for _ in range(rows)],
    "route_id": np.random.randint(500, 800, rows),
    "zip_code": np.random.randint(10000, 99999, rows),
    "delivery_time_mins": np.random.randint(15, 180, rows),
    "traffic_delay_mins": np.random.randint( 0, 45, rows),
    "fuel_consumption_gallons": np.random.uniform( 1.0, 8.0, rows),
    "gps_signal_quality": np.random.choice(["Good", "Weak"], rows, p=[0.9, 0.1]),
    "weather_condition": np.random.choice(["Clear", "Rain", "Snow"], rows),
    "delivery_status": np.random.choice(["On-Time", "Late"], rows, p=[0.83, 0.17])
})

# %%
df.head(10)
# Out:
#    package_id         driver_name     delivery_city  \
# 0           1         James White        Nortonfurt
# 1           2       Shelley Lopez     West Ryanside
# 2           3         Isaiah Wood      North Robert
# 3           4   Dr. Amanda Watson      Aaronchester
# 4           5    Katherine Nguyen      Caseyborough
# 5           6    Dr. Ann Martinez  West Melissaland
# 6           7        Keith Harris     Hermanchester
# 7           8  Christopher Murray  New Kellychester
# 8           9        Ryan Herrera      Michaelhaven
# 9          10       Barbara Brown       East Deanna
#
#                                     delivery_address  route_id  zip_code  \
# 0           25626 Daryl Stream, Wagnerberg, MI 57829       602     48187
# 1  2025 Sanchez Spurs Apt. 297, Stephenfurt, DE 7...       770     58481
# 2  5620 Prince Tunnel Apt. 969, Phillipsbury, MP ...       606     38475
# 3  05545 Todd Points Apt. 152, North Kimberly, RI...       571     54552
# 4  245 Johnson Mountain Suite 793, East William, ...       688     77969
# 5             0666 Martinez Walk, Deanfort, AS 94836       520     86534
# 6          0434 Jean Avenue, Lake Danielle, AK 13033       602     16858
# 7  13982 Graham Street, North Jenniferbury, MA 41893       621     84486
# 8              309 Ivan Haven, Colleenfurt, WV 76546       714     84474
# 9           886 Melanie Ports, Vargasville, GA 07103       587     35168
#
#    delivery_time_mins  traffic_delay_mins  fuel_consumption_gallons  \
# 0                  35                   8                  1.535546
# 1                 118                  27                  2.363224
# 2                  93                  27                  3.944121
# 3                  51                  12                  7.214887
# 4                  59                  17                  4.723401
# 5                 156                  11                  6.239450
# 6                  57                   7                  2.219012
# 7                 130                  22                  1.741847
# 8                  99                   4                  2.677322
# 9                  98                   6                  3.197163
#
#   gps_signal_quality weather_condition delivery_status
# 0               Good              Rain            Late
# 1               Good              Snow         On-Time
# 2               Good              Snow         On-Time
# 3               Good              Rain         On-Time
# 4               Good              Snow         On-Time
# 5               Good             Clear            Late
# 6               Good             Clear         On-Time
# 7               Weak             Clear         On-Time
# 8               Good             Clear            Late
# 9               Good              Rain         On-Time
